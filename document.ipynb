# %% [markdown]
# # Business.json
# - PA 지역 Philadelphia 도시
# - 필요없는 column 제거
# - 음식점 카테고리만 선택

# %% [markdown]
# yelp_academic_dataset_business.json

# %% [markdown]
# | Column        | Non-Null Count | Dtype   |
# |:--------------|:---------------|:--------|
# | business_id   | 150346         | object  |
# | name          | 150346         | object  |
# | address       | 150346         | object  |
# | city          | 150346         | object  |
# | state         | 150346         | object  |
# | postal_code   | 150346         | object  |
# | latitude      | 150346         | float64 |
# | longitude     | 150346         | float64 |
# | stars         | 150346         | float64 |
# | review_count  | 150346         | int64   |
# | is_open       | 150346         | int64   |
# | attributes    | 136602         | object  |
# | categories    | 150243         | object  |
# | hours         | 127123         | object  |

# %% [markdown]
# 📍 각 주(state)별 음식점 개수:
# | business_count   |   count |
# |------------------|---------|
# | PA               |   15076 |
# | FL               |   10661 |
# | TN               |    5144 |
# | IN               |    5050 |
# | MO               |    4986 |
# | LA               |    4416 |
# | NJ               |    4031 |
# | AZ               |    3308 |
# | AB               |    2902 |
# | NV               |    2176 |
# | ID               |    1653 |
# | CA               |    1532 |
# | IL               |    1144 |
# | DE               |    1115 |
# | NC               |       1 |
# | CO               |       1 |
# | HI               |       1 |
# | MT               |       1 |
# | XMS              |       1 |

# %% [markdown]
# 📍 PA 지역 내 도시(city)별 음식점 개수:
# | business_count   |   count |
# |------------------|---------|
# | Philadelphia     |    6911 |
# | West Chester     |     329 |
# | Bensalem         |     196 |
# | Norristown       |     192 |
# | Doylestown       |     190 |
# | King of Prussia  |     189 |
# | Phoenixville     |     173 |
# | Exton            |     170 |
# | Media            |     168 |
# | Lansdale         |     160 |
# | Pottstown        |     154 |
# | Wayne            |     152 |
# | Ardmore          |     149 |
# | Levittown        |     137 |
# | Newtown          |     137 |
# | Malvern          |     133 |
# | New Hope         |     129 |
# | Langhorne        |     123 |
# | North Wales      |     120 |
# | Conshohocken     |     120 |

# %% [markdown]
# # review.json
# - PA 지역 philadelphia 도시
# - 필요없는 column 제거
# - 선호도 평점 -> 감성분석 (1,2 부정 | 3 중립 | 4,5 긍정)

# %% [markdown]
# yelp_academic_dataset_review.json

# %% [markdown]
# | Column       | Non-Null Count |       Dtype       |
# |:-------------|:----------------|:------------------|
# | review_id    | 6990280         | object            |
# | user_id      | 6990280         | object            |
# | business_id  | 6990280         | object            |
# | stars        | 6990280         | int64             |
# | useful       | 6990280         | int64             |
# | funny        | 6990280         | int64             |
# | cool         | 6990280         | int64             |
# | text         | 6990280         | object            |
# | date         | 6990280         | datetime64[ns]    |

# %% [markdown]
# 📍 전체 음식점 리뷰 개수:
# | Column       | Non-Null Count |       Dtype       |
# |:-------------|:----------------|:------------------|
# | review_id    | 5069543         | object            |
# | user_id      | 5069543         | object            |
# | business_id  | 5069543         | object            |
# | stars        | 5069543         | int64             |
# | useful       | 5069543         | int64             |
# | text         | 5069543         | object            |
# | date         | 5069543         | datetime64[ns]    |

# %% [markdown]
# 📍 PA 도시별 음식점 리뷰 개수:
# |  state  |       city        | review_count |
# |:-------:|:-----------------:|:------------:|
# |   PA    |   Philadelphia     |    732435    |
# |   PA    | King of Prussia    |     17832    |
# |   PA    |   West Chester     |     17510    |
# |   PA    |       Wayne        |     11905    |
# |   PA    |       Media        |     11706    |
# |   PA    |   Conshohocken     |     11079    |
# |   PA    |      Ardmore       |     11071    |
# |   PA    |     New Hope       |     11044    |
# |   PA    |    Doylestown      |     10507    |
# |   PA    |     Bensalem       |      9860    |
# |   PA    |   Phoenixville     |      9702    |
# |   PA    |       Exton        |      9264    |
# |   PA    |      Newtown       |      8680    |
# |   PA    |      Malvern       |      8546    |
# |   PA    |   North Wales      |      8429    |
# |   PA    |     Lansdale       |      8127    |
# |   PA    |   Willow Grove     |      8118    |
# |   PA    |    Norristown      |      7709    |
# |   PA    |     Bryn Mawr      |      6974    |
# |   PA    |   Collegeville     |      6627    |

# %% [markdown]
# 📍 이모지 개수별 리뷰 수 분포
#
# | emoji_count | review_count |
# |:-----------:|:------------:|
# |      0      |    732331    |
# |      1      |       76     |
# |      2      |       15     |
# |      3      |        5     |
# |      4      |        2     |
# |      5      |        2     |
# |      6      |        1     |
# |      8      |        1     |
# |      9      |        1     |
# |     11      |        1     |

# %% [markdown]
# # user.json
# - 필요 없는 column 제거
# - PA지역 Philadelphia 도시에 review 5개 이상 작성한 사용자

# %% [markdown]
# yelp_academic_dataset_user.json

# %% [markdown]
# | Column              | Non-Null Count |   Dtype   |
# |:--------------------|:----------------|:----------|
# | user_id             | 1987897         | object    |
# | name                | 1987897         | object    |
# | review_count        | 1987897         | int64     |
# | yelping_since       | 1987897         | object    |
# | useful              | 1987897         | int64     |
# | funny               | 1987897         | int64     |
# | cool                | 1987897         | int64     |
# | elite               | 1987897         | object    |
# | friends             | 1987897         | object    |
# | fans                | 1987897         | int64     |
# | average_stars       | 1987897         | float64   |
# | compliment_hot      | 1987897         | int64     |
# | compliment_more     | 1987897         | int64     |
# | compliment_profile  | 1987897         | int64     |
# | compliment_cute     | 1987897         | int64     |
# | compliment_list     | 1987897         | int64     |
# | compliment_note     | 1987897         | int64     |
# | compliment_plain    | 1987897         | int64     |
# | compliment_cool     | 1987897         | int64     |
# | compliment_funny    | 1987897         | int64     |
# | compliment_writer   | 1987897         | int64     |
# | compliment_photos   | 1987897         | int64     |

# %% [markdown]
# - PA-Philadelphia 지역
# - 리뷰 수 5개 이상 작성
# - User
#
# | Column         | Non-Null Count |   Dtype   |
# |:---------------|:----------------|:----------|
# | user_id        | 28518           | object    |
# | name           | 28518           | object    |
# | review_count   | 28518           | int64     |
# | useful         | 28518           | int64     |
# | average_stars  | 28518           | float64   |

# %% [markdown]
# # Cleaning

# %% [markdown]
# ### 📊 전처리 후 리뷰 단어 수 통계
#
# | 항목             | 값          |
# |------------------|--------------|
# | 총 리뷰 수        | 732,435      |
# | 평균 길이         | 47.48 단어   |
# | 표준편차          | 40.99 단어   |
# | 최솟값            | 0 단어       |
# | 25% 분위수        | 20 단어      |
# | 중앙값 (50%)      | 35 단어      |
# | 75% 분위수        | 61 단어      |
# | 최댓값            | 638 단어     |

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 🧾 RoBERTa 토큰 초과 리뷰 통계
#
# | 기준 토큰 수 | 초과 리뷰 수 | 전체 대비 비율 |
# |---------------|---------------|-----------------|
# | 128           | 55,665         | 7.60%           |
# | 256           | 6,135          | 0.84%           |
# | 512           | 180            | 0.02%           |

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Issue

# %% [markdown]
# 🔄 RoBERTa 벡터화 중:   1%|          | 10909/1598960 [08:47<21:19:45, 20.68line/s]

# %% [markdown]
# 🚀 RoBERTa 벡터화 중 (batch):   6%|▌         | 41282/732435 [06:45<1:55:16, 99.93line/s]
